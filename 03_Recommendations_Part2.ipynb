# %% [markdown]
# <a href="https://colab.research.google.com/github/mneedham/data-science-training/blob/master/03_Recommendations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Recommendations: Part 2
#
# In the 2nd part of our recommendations notebook, we're going to use the PageRank algorithm to make article recommendations to an author. Let's import our libraries in case we don't have those from the previous notebooks:

# %% [markdown]
# And let's import those libraries:

# %%
from neo4j import GraphDatabase
import pandas as pd

import matplotlib 
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.max_colwidth', 100)

# %% [markdown]
# Update the cell below with the same Sandbox credentials that you used in the first notebook:

# %%
driver = GraphDatabase.driver("bolt://data-science-training-neo4j", auth=("neo4j", "admin"))        
print(driver.address)
# Out:
# Address(host='data-science-training-neo4j', port=7687)

# %% [markdown]
# ## PageRank
#
# We're going to use the PageRank algorithm, so let's first get up to speed on this algorithm.
#
# PageRank is an algorithm that measures the transitive influence or connectivity of nodes. It can be computed by either iteratively distributing one node’s rank (originally based on degree) over its neighbours or by randomly traversing the graph and counting the frequency of hitting each node during these walks.
#
# We can run PageRank over the whole graph to find out the most influential article in terms of citations:

# %%
query = """
CALL gds.pageRank.write({
  nodeProjection: "Article",
  relationshipProjection: "CITED",
  writeProperty: "pagerank"
})
"""

with driver.session() as session:
    result = session.run(query)

pd.DataFrame([dict(record) for record in result])
# Out:
#    computeMillis  \
# 0            842
#
#                                                                                          configuration  \
# 0  {'maxIterations': 20, 'writeConcurrency': 4, 'sourceNodes': [], 'writeProperty': 'pagerank', 're...
#
#    createMillis  didConverge  nodePropertiesWritten  ranIterations  \
# 0           421        False                  51956             20
#
#    writeMillis
# 0          839

# %% [markdown]
# This query stores a 'pagerank' property on each node. We can write the following query to view the most influential articles:

# %%
query = """
MATCH (a:Article) 
RETURN a.title as article, a.pagerank as score 
ORDER BY score DESC 
LIMIT 10 
""" 

with driver.session() as session:
    result = session.run(query)

pd.DataFrame([dict(record) for record in result])
# Out:
#                                                                                              article  \
# 0                             A method for obtaining digital signatures and public-key cryptosystems
# 1                                                       Secure communications over insecure channels
# 2                                                                                         Rough sets
# 3                                                        An axiomatic basis for computer programming
# 4  Pastry: Scalable, Decentralized Object Location, and Routing for Large-Scale Peer-to-Peer Systems
# 5                              SCRIBE: The Design of a Large-Scale Event Notification Infrastructure
# 6                                     A field study of the software design process for large systems
# 7                                                  Productivity factors and programming environments
# 8                                                        Analyzing medium-scale software development
# 9                                                                A Calculus of Communicating Systems
#
#    score
# 0 93.943
# 1 79.869
# 2 25.609
# 3 23.029
# 4 21.470
# 5 19.486
# 6 19.028
# 7 18.499
# 8 16.453
# 9 15.431

# %% [markdown]
# ## Personalized PageRank
#
# Personalized PageRank is a variant of PageRank that allows us to find influential nodes based on a set of source nodes.
#
# For example, rather than finding the overall most influential articles, we could instead find the most influential articles with respect to a given author.

# %%
query = """
MATCH (a:Author {name: $author})<-[:AUTHOR]-(article)-[:CITED]->(other)
WITH collect(article) + collect(other) AS sourceNodes
CALL gds.pageRank.stream({
  nodeProjection: 'Article', 
  relationshipProjection: 'CITED', 
  sourceNodes: sourceNodes
})
YIELD nodeId, score
WITH gds.util.asNode(nodeId) AS node, score
WHERE not node in sourceNodes
RETURN node.title AS article, score, [(node)-[:AUTHOR]->(author) | author.name] AS authors
ORDER BY score DESC
LIMIT 10
"""

author_name = "Whitfield Diffie"
with driver.session() as session:
    result = session.run(query, {"author": author_name})

pd.DataFrame([dict(record) for record in result])
# Out:
#                                                                                              article  \
# 0                             A method for obtaining digital signatures and public-key cryptosystems
# 1                                                       Secure communications over insecure channels
# 2                                                                                         Rough sets
# 3                                                        An axiomatic basis for computer programming
# 4  Pastry: Scalable, Decentralized Object Location, and Routing for Large-Scale Peer-to-Peer Systems
# 5                              SCRIBE: The Design of a Large-Scale Event Notification Infrastructure
# 6                                     A field study of the software design process for large systems
# 7                                                  Productivity factors and programming environments
# 8                                                        Analyzing medium-scale software development
# 9                                                                A Calculus of Communicating Systems
#
#                                                                                    authors  \
# 0                                       [Adi Shamir, Leonard M. Adleman, Ronald L. Rivest]
# 1                                                                        [Ralph C. Merkle]
# 2             [Roman Słowiński, Wojciech Ziarko, Jerzy W. Grzymala-Busse, Zdzisław Pawlak]
# 3                                                                         [C. A. R. Hoare]
# 4                                                  [Antony I. T. Rowstron, Peter Druschel]
# 5             [Peter Druschel, Anne-Marie Kermarrec, Antony I. T. Rowstron, Miguel Castro]
# 6                                                  [Bill Curtis, Herb Krasner, Neil Iscoe]
# 7  [S. Hoben, Ray W. Wolverton, John R. Vosburgh, B. Albert, H Malec, Y. Liu, Bill Curtis]
# 8                                                  [Victor R. Basili, Marvin V. Zelkowitz]
# 9                                                                           [Robin Milner]
#
#    score
# 0 93.943
# 1 79.869
# 2 25.609
# 3 23.029
# 4 21.470
# 5 19.486
# 6 19.028
# 7 18.499
# 8 16.453
# 9 15.431

# %% [markdown]
# ## Topic Sensitive Search
#
# We can also use Personalized PageRank to do 'Topic Specific PageRank'.
#
# When an author is searching for articles to read, they want that search to take them into account. Two authors using the same search term would expect to see different results depending on their area of research.
#
# We'll start by creating a full text search index on the 'title' and 'abstract' properties of all nodes that have the label 'Article':

# %% [markdown]
# And let's have a look what articles they've published and how many citations they've received:

# %%
query = """
CALL db.index.fulltext.createNodeIndex('articles', ['Article'], ['title', 'abstract'])
"""

with driver.session() as session:
    session.run(query).summary()
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-12-541f8a8a020e> in <module>
#       4
#       5 with driver.session() as session:
# ----> 6     session.run(query).summary()
#
# /opt/conda/lib/python3.7/site-packages/neo4j/__init__.py in run(self, statement, parameters, **kwparameters)
#     501             try:
#     502                 self._connection.send()
# --> 503                 self._connection.fetch()
#     504             except ConnectionExpired as error:
#     505                 raise SessionExpired(*error.args)
#
# /opt/conda/lib/python3.7/site-packages/neobolt/direct.py in fetch(self)
#     417     def fetch(self):
#     418         try:
# --> 419             return self._fetch()
#     420         except self.error_handler.known_errors as error:
#     421             self.error_handler.handle(error, self.unresolved_address)
#
# /opt/conda/lib/python3.7/site-packages/neobolt/direct.py in _fetch(self)
#     459         elif summary_signature == b"\x7F":
#     460             log_debug("[#%04X]  S: FAILURE %r", self.local_port, summary_metadata)
# --> 461             response.on_failure(summary_metadata or {})
#     462         else:
#     463             raise ProtocolError("Unexpected response message with signature %02X" % summary_signature)
#
# /opt/conda/lib/python3.7/site-packages/neobolt/direct.py in on_failure(self, metadata)
#     753         if callable(handler):
#     754             handler()
# --> 755         raise CypherError.hydrate(**metadata)
#     756
#     757     def on_ignored(self, metadata=None):
#
# ClientError: There already exists an index NODE:label[0](property[2], property[5]).

# %% [markdown]
# We can check that our full text index has been created by running the following query:

# %%
query = """
CALL db.indexes()
YIELD description, indexName, tokenNames, properties, state, type, progress
WHERE type = "node_fulltext"
RETURN *
"""
with driver.session() as session:
    result = session.run(query)
pd.DataFrame([dict(record) for record in result])
# Out:
#                               description indexName  progress  \
# 0  INDEX ON NODE:Article(title, abstract)  articles   100.000
#
#           properties   state tokenNames           type
# 0  [title, abstract]  ONLINE  [Article]  node_fulltext

# %% [markdown]
# We can search the full text index like this:

# %%
query = """
CALL db.index.fulltext.queryNodes("articles", $searchTerm)
YIELD node, score
RETURN node.title, score, [(author)<-[:AUTHOR]-(node) | author.name] AS authors
LIMIT 10
"""
with driver.session() as session:
    result = session.run(query, {"searchTerm": "educating"})
pd.DataFrame([dict(record) for record in result])
# Out:
#                                                                                                authors  \
# 0                                                                                   [Peter J. Denning]
# 1                                                                                 [Robert B. Schnabel]
# 2  [F. Díaz del Río, D. Cascado, José Luis Sevillano, F. J. Hurtado-Núñez, F. J. Moriana-García, Lu...
# 3                                                   [Barry W. Boehm, Supannika Koolmanojwong Mobasser]
# 4                                                                        [Daniel Port, Barry W. Boehm]
# 5                                                                     [Ana M. Moreno, Lawrence Peters]
# 6            [Kenji Taguchi, Hironori Washizaki, Shinichi Honiden, Yasuyuki Tahara, Nobukazu Yoshioka]
# 7                                [Thomas Delahunty, Katherine Sewell, Gregory M. P. O'Hare, A. Murphy]
# 8                                                           [Ivica Crnkovic, Marin Orlic, Igor Čavrak]
# 9                                                                                    [Bruria Haberman]
#
#                                                                                             node.title  \
# 0                                                                             Educating a new engineer
# 1                                                                Educating computing's next generation
# 2                         eDiab: a system for monitoring, assisting and educating people with diabetes
# 3                                               System thinking: educating t-shaped software engineers
# 4                                               Educating software engineering students to manage risk
# 5  Educating software engineering managers: revisited: what software project managers need to know ...
# 6  Top SE: Educating Superarchitects Who Can Apply Software Engineering Tools to Practical Developm...
# 7                                                             ECHOES: An Immersive Training Experience
# 8                                  Collaboration patterns in distributed software development projects
# 9                Teaching computing in secondary schools in a dynamic world: challenges and directions
#
#    score
# 0  3.497
# 1  3.497
# 2  3.353
# 3  2.623
# 4  2.623
# 5  1.748
# 6  1.748
# 7  0.835
# 8  0.730
# 9  0.626

# %% [markdown]
# We can write the following query to find the authors that have published the most articles on 'open source':

# %%
query = """
CALL db.index.fulltext.queryNodes("articles", "open source")
YIELD node AS article, score
MATCH (article)-[:AUTHOR]->(author)
RETURN author.name, sum(score) AS totalScore, collect(article.title) AS articles
ORDER By totalScore DESC
LIMIT 20
"""
with driver.session() as session:
    result = session.run(query)
pd.DataFrame([dict(record) for record in result])
# Out:
#                                                                                                articles  \
# 0   [Open source application spaces: the 5th workshop on open source software engineering, The 3rd w...
# 1   [Open source application spaces: the 5th workshop on open source software engineering, The 3rd w...
# 2   [Open source application spaces: the 5th workshop on open source software engineering, The futur...
# 3   [Open source-style collaborative development practices in commercial projects using GitHub, Mach...
# 4   [Open source application spaces: the 5th workshop on open source software engineering, The 3rd w...
# 5   [A case study of a corporate open source development model, Managing a corporate open source sof...
# 6   [Machine learning-based detection of open source license exceptions, Recommending source code fo...
# 7   [Understanding broadcast based peer review on open source software projects, Peer Review on Open...
# 8   [Understanding broadcast based peer review on open source software projects, Peer Review on Open...
# 9   [An automated tool for generating change report from open-source software, Cross project change ...
# 10  [Risk assessment in open source systems, QuESo a quality model for open source software ecosyste...
# 11                       [A look at the economics of open source, A sociopolitical look at open source]
# 12  [A case study of a corporate open source development model, Managing a corporate open source sof...
# 13  [A case study of a corporate open source development model, Managing a corporate open source sof...
# 14  [The 3rd workshop on open source software engineering, Collaboration, conflict and control: the ...
# 15  [Disseminating architectural knowledge on open-source projects: a case study of the book "archit...
# 16  [Where does this code come from and where does it go? - integrated code history tracker for open...
# 17  [Open implementation design guidelines, A degree-of-knowledge model to capture source code famil...
# 18  [Toward an understanding of the motivation of open source software developers, A case study of t...
# 19  [The hard life of open source software project newcomers, Overcoming open source project entry b...
#
#                 author.name  totalScore
# 0          Brian Fitzgerald      16.119
# 1             Joseph Feller      16.012
# 2              Walt Scacchi      10.731
# 3          Daniel M. German      10.687
# 4           Scott A. Hissam      10.642
# 5         James D. Herbsleb      10.476
# 6          Denys Poshyvanyk       8.907
# 7   Margaret-Anne D. Storey       8.181
# 8            Peter C. Rigby       7.649
# 9          Ruchika Malhotra       7.132
# 10            Xavier Franch       7.117
# 11          Robert L. Glass       6.984
# 12         Vijay K. Gurbani       6.689
# 13            Anita Garvert       6.689
# 14         Karim R. Lakhani       6.560
# 15      Martin P. Robillard       6.414
# 16            Katsuro Inoue       6.190
# 17           Gail C. Murphy       6.134
# 18          Kouichi Kishida       5.563
# 19         Igor Steinmacher       5.491

# %% [markdown]
# We can now use Full Text Search and Personalized PageRank to find interesting articles for different authors.

# %%
query = """
MATCH (a:Article)-[:AUTHOR]->(author:Author)
WHERE author.name=$authorName
WITH author, collect(a) as articles
CALL gds.pageRank.stream({
  nodeQuery: 'CALL db.index.fulltext.queryNodes("articles", $searchTerm)
              YIELD node, score
              RETURN id(node) as id',
  relationshipQuery: 'MATCH (a1:Article)-[:CITED]->(a2:Article) 
                      RETURN id(a1) as source,id(a2) as target', 
  sourceNodes: articles, 
  validateRelationships: false,
  parameters: {searchTerm: $searchTerm}
})
YIELD nodeId, score
WITH gds.util.asNode(nodeId) AS n, score
WHERE not(exists((author)<-[:AUTHOR]-(n)))
RETURN n.title as article, score, [(n)-[:AUTHOR]->(author) | author.name][..5] AS authors
order by score desc limit 10
"""

params = {"authorName": "Tao Xie", "searchTerm": "open source"}

with driver.session() as session:
    result = session.run(query, params)
pd.DataFrame([dict(record) for record in result])
# Out:
#                                                                                        article  \
# 0                                     Static detection of cross-site scripting vulnerabilities
# 1                                     Characterizing logging practices in open-source software
# 2                Automated, contract-based user testing of commercial-off-the-shelf components
# 3        Concern graphs: finding and describing concerns using structural program dependencies
# 4                                                                      Who should fix this bug
# 5                                        Conceptual module querying for software reengineering
# 6                                                       IBM's pragmatic embrace of open source
# 7                                                     Open courseware and open source software
# 8  Reusing Open-Source Software and Practices: The Impact of Open-Source on Commercial Vendors
# 9                                                        From Research Software to Open Source
#
#                                              authors  score
# 0                     [Gary Wassermann, Zhendong Su]  0.236
# 1            [Ding Yuan, Soyeon Park, Yuanyuan Zhou]  0.128
# 2  [Michal M. Sówka, Lionel C. Briand, Yvan Labiche]  0.128
# 3              [Gail C. Murphy, Martin P. Robillard]  0.128
# 4          [Gail C. Murphy, Lyndon Hiew, John Anvik]  0.128
# 5            [Gail C. Murphy, Elisa L. A. Baniassad]  0.108
# 6                                 [Pamela Samuelson]  0.000
# 7   [Hauke Heier, Anett Mehler-Bicher, Stefan Baldi]  0.000
# 8                       [Alan W. Brown, Grady Booch]  0.000
# 9                                  [Susan L. Graham]  0.000

# %%
params = {"authorName": "Margus Veanes", "searchTerm": "open source"}
with driver.session() as session:
    result = session.run(query, params)
pd.DataFrame([dict(record) for record in result])
# Out:
#                                                                                     article  \
# 0                                                                Crypto policy perspectives
# 1                                                             Reassessing the crypto debate
# 2                                            Enabling crypto: how radical innovations occur
# 3  A novel hybrid crypto-biometric authentication scheme for ATM based banking applications
# 4                        Case study of a fault attack on asynchronous DES crypto-processors
# 5                                    A Survey of Name-Passing Calculi and Crypto-Primitives
# 6                                                                     Crypto key management
# 7     Neuroscience meets cryptography: crypto primitives secure against rubber hose attacks
# 8                                                             A plain text on crypto policy
# 9                                                              Crypto backup and key escrow
#
#                                                                                     authors  \
# 0          [Susan Landau, Dorothy E. Denning, Anthony G. Lauck, David Sobel, Scott Charney]
# 1                                                                        [Peter G. Neumann]
# 2                                                                              [Arnd Weber]
# 3                                [Jie Zhou, Jiankun Hu, Yong Feng, Fengling Han, Xinhuo Yu]
# 4       [Christophe Clavier, Yannick Monnet, Pascal Moitrel, Marc Renaudin, Régis Leveugle]
# 5  [Giuseppe Castagna, Riccardo Focardi, Michele Bugliesi, Silvia Crafa, Vladimiro Sassone]
# 6                                                                        [Peter G. Neumann]
# 7            [Patrick Lincoln, Daniel J. Sanchez, Dan Boneh, Hristo Bojinov, Paul J. Reber]
# 8                                                                       [John Perry Barlow]
# 9                                                                          [David P. Maher]
#
#    score
# 0  0.278
# 1  0.150
# 2  0.150
# 3  0.150
# 4  0.150
# 5  0.150
# 6  0.150
# 7  0.150
# 8  0.150
# 9  0.150

# %% [markdown]
# Let's try the same query with a different author:

# %%
params = {"authorName": "Marco Aurélio Gerosa", "searchTerm": "open source"}

with driver.session() as session:
    result = session.run(query, params)
pd.DataFrame([dict(record) for record in result])
