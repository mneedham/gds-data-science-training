# %% [markdown]
# <a href="https://colab.research.google.com/github/mneedham/data-science-training/blob/master/03_Recommendations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Recommendations: Part 2
#
# In the 2nd part of our recommendations notebook, we're going to use the PageRank algorithm to make article recommendations to an author. Let's import our libraries in case we don't have those from the previous notebooks:

# %% [markdown]
# And let's import those libraries:

# %%
from neo4j import GraphDatabase
import pandas as pd

import matplotlib 
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.max_colwidth', 100)

# %% [markdown]
# Update the cell below with the same Sandbox credentials that you used in the first notebook:

# %%
driver = GraphDatabase.driver("bolt://data-science-training-neo4j", auth=("neo4j", "admin"))        
print(driver.address)
# Out:
# Address(host='data-science-training-neo4j', port=7687)

# %% [markdown]
# ## PageRank
#
# We're going to use the PageRank algorithm, so let's first get up to speed on this algorithm.
#
# PageRank is an algorithm that measures the transitive influence or connectivity of nodes. It can be computed by either iteratively distributing one node’s rank (originally based on degree) over its neighbours or by randomly traversing the graph and counting the frequency of hitting each node during these walks.
#
# We can run PageRank over the whole graph to find out the most influential article in terms of citations:

# %%
query = """
CALL gds.pageRank.write({
  nodeProjection: "Article",
  relationshipProjection: "CITED",
  writeProperty: "pagerank"
})
"""

with driver.session() as session:
    result = session.run(query)

pd.DataFrame([dict(record) for record in result])
# Out:
#    computeMillis  \
# 0           1004
#
#                                                                                          configuration  \
# 0  {'maxIterations': 20, 'writeConcurrency': 4, 'sourceNodes': [], 'writeProperty': 'pagerank', 're...
#
#    createMillis  didConverge  nodePropertiesWritten  ranIterations  \
# 0           607        False                  51956             20
#
#    writeMillis
# 0          732

# %% [markdown]
# This query stores a 'pagerank' property on each node. We can write the following query to view the most influential articles:

# %%
query = """
MATCH (a:Article) 
RETURN a.title as article, a.pagerank as score, a.year, [(a)-[:AUTHOR]->(au) | au.name]
ORDER BY score DESC 
LIMIT 10 
""" 

with driver.session() as session:
    result = session.run(query)

pd.DataFrame([dict(record) for record in result])
# Out:
#                                                            [(a)-[:AUTHOR]->(au) | au.name]  \
# 0                                       [Adi Shamir, Leonard M. Adleman, Ronald L. Rivest]
# 1                                                                        [Ralph C. Merkle]
# 2             [Roman Słowiński, Wojciech Ziarko, Jerzy W. Grzymala-Busse, Zdzisław Pawlak]
# 3                                                                         [C. A. R. Hoare]
# 4                                                  [Antony I. T. Rowstron, Peter Druschel]
# 5             [Peter Druschel, Anne-Marie Kermarrec, Antony I. T. Rowstron, Miguel Castro]
# 6                                                  [Bill Curtis, Herb Krasner, Neil Iscoe]
# 7  [S. Hoben, Ray W. Wolverton, John R. Vosburgh, B. Albert, H Malec, Y. Liu, Bill Curtis]
# 8                                                  [Victor R. Basili, Marvin V. Zelkowitz]
# 9                                                                           [Robin Milner]
#
#    a.year  \
# 0    1978
# 1    1978
# 2    1995
# 3    1969
# 4    2001
# 5    2001
# 6    1988
# 7    1984
# 8    1978
# 9    1982
#
#                                                                                              article  \
# 0                             A method for obtaining digital signatures and public-key cryptosystems
# 1                                                       Secure communications over insecure channels
# 2                                                                                         Rough sets
# 3                                                        An axiomatic basis for computer programming
# 4  Pastry: Scalable, Decentralized Object Location, and Routing for Large-Scale Peer-to-Peer Systems
# 5                              SCRIBE: The Design of a Large-Scale Event Notification Infrastructure
# 6                                     A field study of the software design process for large systems
# 7                                                  Productivity factors and programming environments
# 8                                                        Analyzing medium-scale software development
# 9                                                                A Calculus of Communicating Systems
#
#    score
# 0 93.943
# 1 79.869
# 2 25.609
# 3 23.029
# 4 21.470
# 5 19.486
# 6 19.028
# 7 18.499
# 8 16.453
# 9 15.431

# %% [markdown]
# ## Personalized PageRank
#
# Personalized PageRank is a variant of PageRank that allows us to find influential nodes based on a set of source nodes.
#
# For example, rather than finding the overall most influential articles, we could instead find the most influential articles with respect to a given author.

# %%
query = """
MATCH (a:Author {name: $author})<-[:AUTHOR]-(article)-[:CITED]->(other)
WITH collect(article) + collect(other) AS sourceNodes
CALL gds.pageRank.stream({
  nodeProjection: 'Article', 
  relationshipProjection: 'CITED', 
  sourceNodes: sourceNodes
})
YIELD nodeId, score
WITH gds.util.asNode(nodeId) AS node, score
WHERE not node in sourceNodes
RETURN node.title AS article, score, [(node)-[:AUTHOR]->(author) | author.name] AS authors
ORDER BY score DESC
LIMIT 10
"""

author_name = "Josef Kittler"
with driver.session() as session:
    result = session.run(query, {"author": author_name})

pd.DataFrame([dict(record) for record in result])
# Out:
#                                                                                                article  \
# 0                                                  BioEVA: An Evaluation Tool for Biometric Algorithms
# 1                         Using Classpects for Integrating Non-Functional and Functional Requirements.
# 2                         Solution Proposals for Japan-Oriented Offshore Software Development in China
# 3                                Mapping Requirements to Software Architecture by Feature-Orientation.
# 4                                QoS Signaling for Parameterized Traffic in IEEE 802.11e Wireless LANs
# 5  Specification of Adleman's Restricted Model Using an Automated Reasoning System: Verification of...
# 6                            Utility function induced by fuzzy target in probabilistic decision making
# 7                      Distributed Process Management System Based on Object-Centered Process Modeling
# 8                                                              Seizing Power: Shaders and Storytellers
# 9  Experience with Global Analysis: A Practical Method for Analyzing Factors that Influence Softwar...
#
#                                                                                                authors  \
# 0                   [Luiz H. R. Sucupira, Miguel Gustavo Lizárraga, Lee Luan Ling, Lívia C. F. Araújo]
# 1                                                                        [Doo-Hwan Bae, Tegegne Marew]
# 2  [Lei Zhang, Jun Hosoya, Ryota Mibe, Xuan Zhang, Meiping Chai, Yoji Taniguchi, Yibing Tan, Shiger...
# 3                                                                              [Dongyun Liu, Hong Mei]
# 4                                                                      [Sunghyun Choi, N. Sai Shankar]
# 5                            [C. Graciani Díaz, Mario J. Pérez-Jiménez, Francisco-Jesús Martín-Mateos]
# 6                                                       [Van-Nam Huynh, Yoshiteru Nakamori, Tu Bao Ho]
# 7                                       [Makoto Oshita, Katsuro Inoue, Hajimu Iida, Makoto Matsushita]
# 8                                                                                       [Kevin Bjorke]
# 9                                                                         [Dilip Soni, Robert L. Nord]
#
#    score
# 0  0.000
# 1  0.000
# 2  0.000
# 3  0.000
# 4  0.000
# 5  0.000
# 6  0.000
# 7  0.000
# 8  0.000
# 9  0.000

# %% [markdown]
# ## Topic Sensitive Search
#
# We can also use Personalized PageRank to do 'Topic Specific PageRank'.
#
# When an author is searching for articles to read, they want that search to take them into account. Two authors using the same search term would expect to see different results depending on their area of research.
#
# We'll start by creating a full text search index on the 'title' and 'abstract' properties of all nodes that have the label 'Article':

# %% [markdown]
# And let's have a look what articles they've published and how many citations they've received:

# %%
query = """
CALL db.index.fulltext.createNodeIndex('articles', ['Article'], ['title', 'abstract'])
"""

with driver.session() as session:
    session.run(query).summary()
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-10-541f8a8a020e> in <module>
#       4
#       5 with driver.session() as session:
# ----> 6     session.run(query).summary()
#
# /opt/conda/lib/python3.7/site-packages/neo4j/__init__.py in run(self, statement, parameters, **kwparameters)
#     501             try:
#     502                 self._connection.send()
# --> 503                 self._connection.fetch()
#     504             except ConnectionExpired as error:
#     505                 raise SessionExpired(*error.args)
#
# /opt/conda/lib/python3.7/site-packages/neobolt/direct.py in fetch(self)
#     417     def fetch(self):
#     418         try:
# --> 419             return self._fetch()
#     420         except self.error_handler.known_errors as error:
#     421             self.error_handler.handle(error, self.unresolved_address)
#
# /opt/conda/lib/python3.7/site-packages/neobolt/direct.py in _fetch(self)
#     459         elif summary_signature == b"\x7F":
#     460             log_debug("[#%04X]  S: FAILURE %r", self.local_port, summary_metadata)
# --> 461             response.on_failure(summary_metadata or {})
#     462         else:
#     463             raise ProtocolError("Unexpected response message with signature %02X" % summary_signature)
#
# /opt/conda/lib/python3.7/site-packages/neobolt/direct.py in on_failure(self, metadata)
#     753         if callable(handler):
#     754             handler()
# --> 755         raise CypherError.hydrate(**metadata)
#     756
#     757     def on_ignored(self, metadata=None):
#
# ClientError: There already exists an index NODE:label[0](property[2], property[5]).

# %% [markdown]
# We can check that our full text index has been created by running the following query:

# %%
query = """
CALL db.indexes()
YIELD description, indexName, tokenNames, properties, state, type, progress
WHERE type = "node_fulltext"
RETURN *
"""
with driver.session() as session:
    result = session.run(query)
pd.DataFrame([dict(record) for record in result])
# Out:
#                               description indexName  progress  \
# 0  INDEX ON NODE:Article(title, abstract)  articles   100.000
#
#           properties   state tokenNames           type
# 0  [title, abstract]  ONLINE  [Article]  node_fulltext

# %% [markdown]
# We can search the full text index like this:

# %%
query = """
CALL db.index.fulltext.queryNodes("articles", $searchTerm)
YIELD node, score
RETURN node.title, score, [(author)<-[:AUTHOR]-(node) | author.name] AS authors
LIMIT 10
"""
with driver.session() as session:
    result = session.run(query, {"searchTerm": "cryptosystems"})
pd.DataFrame([dict(record) for record in result])
# Out:
#                                                           authors  \
# 0        [Katsunori Tanaka, Shigenori Uchiyama, Tatsuaki Okamoto]
# 1                                      [Wen Ping Ma, Moon Ho Lee]
# 2                                              [Tatsuaki Okamoto]
# 3                                              [Ross J. Anderson]
# 4                       [Michael J. Wiener, Robert J. Zuccherato]
# 5                                                 [Patrick Felke]
# 6                                             [Kristian Gjøsteen]
# 7                                [Sachar Paulus, Detlef Hühnlein]
# 8  [Moti Yung, Jean-Jacques Quisquater, Marc Joye, Sung-Ming Yen]
# 9       [Siddika Berna Örs, G Geeke Bruin-Muurling, Lejla Batina]
#
#                                                                      node.title  \
# 0                                              Quantum public-key cryptosystems
# 1                Group oriented cryptosystems based on linear access structures
# 2                                                On pairing-based cryptosystems
# 3                                                        Why cryptosystems fail
# 4                                Faster Attacks on Elliptic Curve Cryptosystems
# 5  On the affine transformations of HFE-cryptosystems and systems with branches
# 6               Homomorphic cryptosystems based on subgroup membership problems
# 7  On the Implementation of Cryptosystems Based on Real Quadratic Number Fields
# 8           Observability Analysis - Detecting When Improved Cryptosystems Fail
# 9             Flexible Hardware Design for RSA and Elliptic Curve Cryptosystems
#
#    score
# 0  3.782
# 1  3.396
# 2  3.122
# 3  3.122
# 4  3.113
# 5  2.988
# 6  2.951
# 7  2.880
# 8  2.799
# 9  2.799

# %% [markdown]
# We can write the following query to find the authors that have published the most articles on 'open source':

# %%
query = """
CALL db.index.fulltext.queryNodes("articles", "cryptosystems")
YIELD node AS article, score
MATCH (article)-[:AUTHOR]->(author)
RETURN author.name, sum(score) AS totalScore, size(article.title) AS articles
ORDER By totalScore DESC
LIMIT 20
"""
with driver.session() as session:
    result = session.run(query)
pd.DataFrame([dict(record) for record in result])
# Out:
#     articles              author.name  totalScore
# 0         32         Tatsuaki Okamoto       3.782
# 1         32         Katsunori Tanaka       3.782
# 2         32       Shigenori Uchiyama       3.782
# 3         62              Wen Ping Ma       3.396
# 4         62              Moon Ho Lee       3.396
# 5         22         Ross J. Anderson       3.122
# 6         30         Tatsuaki Okamoto       3.122
# 7         46        Michael J. Wiener       3.113
# 8         46     Robert J. Zuccherato       3.113
# 9         76            Patrick Felke       2.988
# 10        63        Kristian Gjøsteen       2.951
# 11        76            Sachar Paulus       2.880
# 12        76          Detlef Hühnlein       2.880
# 13        67  Jean-Jacques Quisquater       2.799
# 14        65             Lejla Batina       2.799
# 15        65   G Geeke Bruin-Muurling       2.799
# 16        65        Siddika Berna Örs       2.799
# 17        67            Sung-Ming Yen       2.799
# 18        67                Marc Joye       2.799
# 19        67                Moti Yung       2.799

# %% [markdown]
# We can now use Full Text Search and Personalized PageRank to find interesting articles for different authors.

# %%
query = """
MATCH (a:Article)-[:AUTHOR]->(author:Author)
WHERE author.name=$authorName
WITH author, collect(a) as articles
CALL gds.pageRank.stream({
  nodeQuery: 'CALL db.index.fulltext.queryNodes("articles", $searchTerm)
              YIELD node, score
              RETURN id(node) as id',
  relationshipQuery: 'MATCH (a1:Article)-[:CITED]->(a2:Article) 
                      RETURN id(a1) as source,id(a2) as target', 
  sourceNodes: articles, 
  validateRelationships: false,
  parameters: {searchTerm: $searchTerm}
})
YIELD nodeId, score
WITH gds.util.asNode(nodeId) AS n, score
WHERE not(exists((author)<-[:AUTHOR]-(n))) AND score > 0
RETURN n.title as article, score, [(n)-[:AUTHOR]->(author) | author.name][..5] AS authors, n.year as year
order by score desc limit 10
"""

params = {"authorName": "Josef Kittler", "searchTerm": "encryption"}

with driver.session() as session:
    result = session.run(query, params)
pd.DataFrame([dict(record) for record in result])
# Out:
#                                                                                                article  \
# 0                               A method for obtaining digital signatures and public-key cryptosystems
# 1                                     REACT: Rapid Enhanced-Security Asymmetric Cryptosystem Transform
# 2                                   Using encryption for authentication in large networks of computers
# 3                                                               Key-insulated public key cryptosystems
# 4                                       The Oracle Diffie-Hellman Assumptions and an Analysis of DHIES
# 5                                                      Computing arbitrary functions of encrypted data
# 6                                                                      Long-lived broadcast encryption
# 7  Fast Implementation and Fair Comparison of the Final Candidates for Advanced Encryption Standard...
# 8                                       Padding Oracle Attacks on the ISO CBC Mode Encryption Standard
# 9                                                                           A Designer’s Guide to KEMs
#
#                                                    authors  score  year
# 0       [Adi Shamir, Leonard M. Adleman, Ronald L. Rivest]  3.277  1978
# 1                    [David Pointcheval, Tatsuaki Okamoto]  0.759  2001
# 2                 [Michael D. Schroeder, Roger M. Needham]  0.687  1978
# 3  [Jonathan Katz, Moti Yung, Yevgeniy Dodis, Shouhuai Xu]  0.523  2002
# 4         [Michel Abdalla, Mihir Bellare, Phillip Rogaway]  0.472  2001
# 5                                           [Craig Gentry]  0.405  2010
# 6           [Avishai Wool, Jessica Staddon, Juan A. Garay]  0.405  2000
# 7                              [Kris Gaj, Pawel Chodowiec]  0.278  2001
# 8                  [Arnold K. L. Yau, Kenneth G. Paterson]  0.278  2004
# 9                                      [Alexander W. Dent]  0.278  2003

# %%
params = {"authorName": "Margus Veanes", "searchTerm": "open source"}
with driver.session() as session:
    result = session.run(query, params)
pd.DataFrame([dict(record) for record in result])
# Out:
#                                                                                       article  \
# 0  TEG: A High-Performance, Scalable, Multi-network Point-to-Point Communications Methodology
# 1                Open MPI: Goals, Concept, and Design of a Next Generation MPI Implementation
# 2       Concern graphs: finding and describing concerns using structural program dependencies
# 3                                       Conceptual module querying for software reengineering
# 4                                                                     Who should fix this bug
# 5                              Hipikat: recommending pertinent software development artifacts
# 6                             Version Sensitive Editing: Change History as a Programming Tool
# 7                          DECKARD: Scalable and Accurate Tree-Based Detection of Code Clones
# 8   Recovering documentation-to-source-code traceability links using latent semantic indexing
# 9                           Coverage is not strongly correlated with test suite effectiveness
#
#                                                                                       authors  \
# 0               [Edgar Gabriel, Thara Angskun, Graham E. Fagg, David J. Daniel, Vishal Sahay]
# 1  [Andrew Lumsdaine, Edgar Gabriel, David J. Daniel, Prabhanjan Kambadur, Richard L. Graham]
# 2                                                       [Gail C. Murphy, Martin P. Robillard]
# 3                                                     [Gail C. Murphy, Elisa L. A. Baniassad]
# 4                                                   [Gail C. Murphy, Lyndon Hiew, John Anvik]
# 5                                                            [Davor Cubranic, Gail C. Murphy]
# 6                                                                           [David L. Atkins]
# 7                           [Zhendong Su, Stéphane Glondu, Ghassan Misherghi, Lingxiao Jiang]
# 8                                                       [Jonathan I. Maletic, Andrian Marcus]
# 9                                                            [Reid Holmes, Laura Inozemtseva]
#
#    score  year
# 0  3.319  2004
# 1  2.870  2004
# 2  2.626  2002
# 3  2.542  1998
# 4  2.342  2006
# 5  2.205  2003
# 6  2.151  1998
# 7  2.145  2007
# 8  2.006  2003
# 9  1.928  2014

# %% [markdown]
# Let's try the same query with a different author:

# %%
params = {"authorName": "Marco Aurélio Gerosa", "searchTerm": "open source"}

with driver.session() as session:
    result = session.run(query, params)
pd.DataFrame([dict(record) for record in result])
# Out:
#                                                                                               article  \
# 0                        Toward an understanding of the motivation of open source software developers
# 1                                Which bug should I fix: helping new developers onboard a new project
# 2                                      Hipikat: recommending pertinent software development artifacts
# 3  Tesseract: Interactive visual exploration of socio-technical relationships in software development
# 4                                     Version Sensitive Editing: Change History as a Programming Tool
# 5       Unifying artifacts and activities in a visual tool for distributed software development teams
# 6                                                                             Progressive open source
# 7                                 A case study of open source software development: the Apache server
# 8          A case study of the evolution of Jun: an object-oriented open-source 3D multimedia library
# 9                               An empirical study of global software development: distance and speed
#
#                                                                               authors  \
# 0                                                        [Yunwen Ye, Kouichi Kishida]
# 1                                                         [Anita Sarma, Jianguo Wang]
# 2                                                    [Davor Cubranic, Gail C. Murphy]
# 3                [Anita Sarma, James D. Herbsleb, Larry Maccherone, Patrick Wagstrom]
# 4                                                                   [David L. Atkins]
# 5                                                       [Paul Dourish, Jon Froehlich]
# 6                        [Rob Miller, Jamie Dinkelacker, Pankaj K. Garg, Dean Nelson]
# 7                                    [James D. Herbsleb, Roy Fielding, Audris Mockus]
# 8  [Kumiyo Nakakoji, Atsushi Aoki, Y. Yamamoto, Yoshiyuki Nishinaka, Kouichi Kishida]
# 9           [Rebecca E. Grinter, Thomas A. Finholt, Audris Mockus, James D. Herbsleb]
#
#    score  year
# 0  0.111  2003
# 1  0.089  2011
# 2  0.080  2003
# 3  0.076  2009
# 4  0.068  1998
# 5  0.064  2004
# 6  0.031  2002
# 7  0.031  2000
# 8  0.031  2001
# 9  0.027  2001
